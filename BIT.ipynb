# %%
#bitwise operators


a = 5 # In binary: 0101
b = 3 # In binary: 0011
print(a & b)  # Bitwise AND
print(a | b)  # Bitwise OR
print(a ^ b)  # Bitwise XOR
print(~a)     # Bitwise NOT
# Out:
# 1
# 7
# 6
# -6
